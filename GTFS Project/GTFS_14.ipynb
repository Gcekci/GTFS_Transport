# %%
import pandas as pd
from datetime import datetime, timedelta
import time
from ipywidgets import HTML
from ipyleaflet import Map, Marker, Popup, basemaps, AwesomeIcon
from IPython.display import display
import mysql.connector
import configparser

config = configparser.ConfigParser()
config.read('config.ini')

data_path = config.get("app", "data_path")
stops = pd.read_csv(f"{data_path}/stops.txt")
routes = pd.read_csv(f"{data_path}/routes.txt")
trips = pd.read_csv(f"{data_path}/trips.txt")
stop_times = pd.read_csv(f"{data_path}/stop_times.txt")
calendar = pd.read_csv(f"{data_path}/calendar.txt")

db = mysql.connector.connect(
    host=config.get("app", "host"),
    user=config.get("app", "user"),
    password=config.get("app", "password"),
    database=config.get("app", "database")
)
cursor = db.cursor()
#If the data with the same trip_id already exist in the table, it only executes the update function instead of inserting and updating together to avoid duplicates.

insert_or_update_buses = ("""
INSERT INTO buses 
(route_short_name, trip_id, service_id, route_id, direction_id, arrival_time, departure_time, stop_id, stop_name, stop_sequence, stop_lat, stop_lon, update_time)
VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
ON DUPLICATE KEY UPDATE 
route_short_name = VALUES(route_short_name), 
service_id = VALUES(service_id), 
route_id = VALUES(route_id), 
direction_id = VALUES(direction_id), 
arrival_time = VALUES(arrival_time), 
departure_time = VALUES(departure_time), 
stop_id = VALUES(stop_id), 
stop_name = VALUES(stop_name), 
stop_sequence = VALUES(stop_sequence), 
stop_lat = VALUES(stop_lat), 
stop_lon = VALUES(stop_lon), 
update_time = VALUES(update_time)
""")

delete_buses = ("DELETE FROM buses WHERE trip_id=%s")


def convert_time(time_str):
    try:
        parts = time_str.split(':')
        hours, minutes, seconds = int(parts[0]), int(parts[1]), int(parts[2])
        if hours >= 24:
            hours -= 24
        return f"{hours:02}:{minutes:02}:{seconds:02}"
    except ValueError as e:
        print(f"Error converting time: {time_str} - {e}")
        return None

stop_times['arrival_time'] = stop_times['arrival_time'].apply(convert_time)
stop_times['departure_time'] = stop_times['departure_time'].apply(convert_time)
stop_times = stop_times.dropna(subset=['arrival_time', 'departure_time'])

update_interval = 30  # second

def get_time_input(prompt):
    while True:
        try:
            time_str = input(prompt)
            time_obj = datetime.strptime(time_str, '%H:%M:%S').time()
            return time_str
        except ValueError:
            print("Invalid time format. Please enter time in HH:MM:SS format.")

def get_service_ids_for_date(date):
    day_index = date.weekday()
    days = ['monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday', 'sunday']
    day_column = days[day_index]
    service_ids = calendar[calendar[day_column] == 1]['service_id'].tolist()
    return service_ids

def get_buses_at_time(target_time_str, service_ids):
    filtered_stop_times = stop_times[
        (stop_times['arrival_time'] == target_time_str) | 
        (stop_times['departure_time'] == target_time_str)
    ]
    
    if filtered_stop_times.empty:
        return []

    filtered_stop_times = pd.merge(filtered_stop_times, trips, on='trip_id', how='left')
    filtered_stop_times = filtered_stop_times[filtered_stop_times['service_id'].isin(service_ids)]
    
    if filtered_stop_times.empty:
        return []

    merged_df = pd.merge(filtered_stop_times, routes, on='route_id', how='left')
    merged_df = pd.merge(merged_df, stops, on='stop_id', how='left')
    
    bus_data = []
    for _, row in merged_df.iterrows():
        routeNumber = row['route_short_name']
        tripID = row['trip_id']
        routeID = row['route_id']
        stopName = row['stop_name']
        arrivalTime = row['arrival_time']
        departureTime = row['departure_time']
        serviceID = row['service_id']
        stopSequence = row['stop_sequence']
        directionID = row['direction_id']
        stopID = row['stop_id']
        stopLat = row['stop_lat']
        stopLon = row['stop_lon']
        print(
        f"Route: {routeNumber}, Trip ID: {tripID}, Stop: {stopID}, Arrival Time: {arrivalTime}, Departure Time: {departureTime}, "
        f"Stop Name: {stopName}, Direction ID: {directionID}, Stop Lat: {stopLat}, Stop Lon: {stopLon}, Route ID: {routeID}, Service ID: {serviceID}, Stop Sequence: {stopSequence}")
        bus_data.append((routeNumber, tripID, serviceID, routeID, directionID, arrivalTime, departureTime,
                         stopID, stopName, stopSequence, stopLat, stopLon))   
    return bus_data

def add_stop_markers(stops_df, mymap, stop_markers):
    for stop in stops_df.itertuples():
        marker = Marker(location=[stop.stop_lat, stop.stop_lon], draggable=False)
        popup_content = HTML()
        popup_content.value = f"Stop: {stop.stop_name}, Stop Number: {stop.stop_id}"
        popup = Popup(location=[stop.stop_lat, stop.stop_lon], child=popup_content)
        marker.popup = popup
        mymap.add_layer(marker)
        stop_markers[stop.stop_id] = marker
    return stop_markers

def create_bus_marker(existing_markers, bus_data):
    stop_lat = bus_data['stop_lat']
    stop_lon = bus_data['stop_lon']
    # Offset step to prevent overlapping markers
    offset = 0.0001

    # Check if a marker already exists at the same location
    for marker in existing_markers.values():
        if abs(marker.location[0] - stop_lat) < offset and abs(marker.location[1] - stop_lon) < offset:
            stop_lat += offset
            stop_lon += offset
            offset += 0.0001

    # Create a new marker at the adjusted location
    icon = AwesomeIcon(name='bus', marker_color='red', icon_color='white')
    new_marker = Marker(icon=icon, location=[stop_lat, stop_lon], draggable=False)
    
    return new_marker

    

def update_popup(marker, bus_data):
    popup_content = HTML()
    popup_content.value = f"Route Name: {bus_data[0]}, Trip ID: {bus_data[1]}, Stop Name: {bus_data[8]}, Arrival Time: {bus_data[5]}"
    marker.popup = Popup(location=marker.location, child=popup_content)

def dynamic_update_service(start_time_str, end_time_str):
    today_date = datetime.now().date()
    start_time = datetime.strptime(start_time_str, '%H:%M:%S').time()
    end_time = datetime.strptime(end_time_str, '%H:%M:%S').time()
    
    start_datetime = datetime.combine(today_date, start_time)
    end_datetime = datetime.combine(today_date, end_time)
    
    if end_time < start_time:
        end_datetime += timedelta(days=1)

    current_datetime = start_datetime
    markers = {}
    stop_markers = {}

    mapcenter = (stops['stop_lat'].mean(), stops['stop_lon'].mean())
    mymap = Map(center=mapcenter, zoom=12, basemap=basemaps.OpenStreetMap.Mapnik)
    
    stop_markers = add_stop_markers(stops, mymap, stop_markers)
    display(mymap)

    while current_datetime <= end_datetime:
        current_time_str = current_datetime.strftime('%H:%M:%S')
        print(f"\nCurrent Time: {current_time_str}")

        current_service_ids = get_service_ids_for_date(current_datetime.date())
        buses = get_buses_at_time(current_time_str, current_service_ids)
        
        if not buses:
            print("No new bus data available, retaining previous state.")

        else:
           
            try:
            # Insert each bus data row into the database
                for data in buses:
                    cursor.execute(insert_or_update_buses,(*data,current_datetime))

            # Commit the transaction to save the data in the database
                    db.commit()

            except mysql.connector.Error as err:
                print(f"Error: {err}")
                db.rollback()  # Rollback the transaction on error

             # trip_id, stop_lat, stop_lon
            for bus_data in buses:
                trip_id = bus_data[1]
                stop_lat, stop_lon = bus_data[10], bus_data[11]
    
                if trip_id in markers:
                    # Update existing marker location and popup
                    marker = markers[trip_id]
                    if marker.location != [stop_lat, stop_lon]:  # Only update if the location has changed
                        marker.location = [stop_lat, stop_lon]
                        update_popup(marker, bus_data)
                else:
                    new_marker = create_bus_marker(markers, {
                        'stop_lat': stop_lat,
                        'stop_lon': stop_lon,
                        
})
                    update_popup(new_marker, bus_data)
                    mymap.add_layer(new_marker)
                    markers[trip_id] = new_marker
                    
        
            try:
                bus_trip_ids = [bus[1] for bus in buses]
                for trip_id in list(markers.keys()):
                    if trip_id not in bus_trip_ids:
                        mymap.remove_layer(markers[trip_id])
                        del markers[trip_id]
                        print(f"Trip ID {trip_id} has completed its trip and has been removed.")
                        
                        cursor.execute(delete_buses, (trip_id,))
                        db.commit()
            except mysql.connector.Error as err:
                                print(f"Error: {err}")
                                db.rollback()  # Rollback the transaction on error
                    
        current_datetime += timedelta(seconds=update_interval)
        time.sleep(3)

start_time_str = get_time_input("Enter start time (HH:MM:SS): ")
end_time_str = get_time_input("Enter end time (HH:MM:SS): ")
dynamic_update_service(start_time_str, end_time_str)
# Out:
# Map(center=[41.39582465849056, 27.357291164150944], controls=(ZoomControl(options=['position', 'zoom_in_text',…
# Current Time: 10:00:00
# Route: 2, Trip ID: 39101-0-5-67674, Stop: 39002, Arrival Time: 10:00:00, Departure Time: 10:00:00, Stop Name: ONUR MARKET, Direction ID: 0, Stop Lat: 41.4057141, Stop Lon: 27.35077, Route ID: 39101, Service ID: 5, Stop Sequence: 3
# Route: 2, Trip ID: 39101-1-5-73648, Stop: 39020, Arrival Time: 10:00:00, Departure Time: 10:00:00, Stop Name: HEAS LOJMANLARI, Direction ID: 1, Stop Lat: 41.3997627, Stop Lon: 27.3763757, Route ID: 39101, Service ID: 5, Stop Sequence: 2
# Route: 3, Trip ID: 39102-1-5-72418, Stop: 39301, Arrival Time: 10:00:00, Departure Time: 10:00:00, Stop Name: ALYA3, Direction ID: 1, Stop Lat: 41.3866935, Stop Lon: 27.3660363, Route ID: 39102, Service ID: 5, Stop Sequence: 1
# Route: 4, Trip ID: 39103-0-5-73067, Stop: 39406, Arrival Time: 10:00:00, Departure Time: 10:00:00, Stop Name: FİDANLIK, Direction ID: 0, Stop Lat: 41.3560923, Stop Lon: 27.3257803, Route ID: 39103, Service ID: 5, Stop Sequence: 8
# Route: 5, Trip ID: 39104-1-5-36111, Stop: 39029, Arrival Time: 10:00:00, Departure Time: 10:00:00, Stop Name: KONGRE MEYDANI, Direction ID: 1, Stop Lat: 41.4067234, Stop Lon: 27.3550605, Route ID: 39104, Service ID: 5, Stop Sequence: 4
# Route: 6, Trip ID: 39105-0-5-42656, Stop: 39046, Arrival Time: 10:00:00, Departure Time: 10:00:00, Stop Name: ECZACIBASI SON DURAK, Direction ID: 0, Stop Lat: 41.4037642, Stop Lon: 27.3751302, Route ID: 39105, Service ID: 5, Stop Sequence: 6
# Route: 6, Trip ID: 39105-1-5-42354, Stop: 39046, Arrival Time: 10:00:00, Departure Time: 10:00:00, Stop Name: ECZACIBASI SON DURAK, Direction ID: 1, Stop Lat: 41.4037642, Stop Lon: 27.3751302, Route ID: 39105, Service ID: 5, Stop Sequence: 1
# Route: 8, Trip ID: 39107-0-5-58004, Stop: 39001, Arrival Time: 10:00:00, Departure Time: 10:00:00, Stop Name: TERMINAL, Direction ID: 0, Stop Lat: 41.4045373, Stop Lon: 27.347064, Route ID: 39107, Service ID: 5, Stop Sequence: 3
# Route: 9, Trip ID: 39108-0-5-59270, Stop: 39039, Arrival Time: 10:00:00, Departure Time: 10:00:00, Stop Name: NOKTA, Direction ID: 0, Stop Lat: 41.4036222, Stop Lon: 27.3640173, Route ID: 39108, Service ID: 5, Stop Sequence: 5
# Route: 9, Trip ID: 39108-1-5-58804, Stop: 39255, Arrival Time: 10:00:00, Departure Time: 10:00:00, Stop Name: DOĞA KOLEJİ, Direction ID: 1, Stop Lat: 41.3908298, Stop Lon: 27.3740549, Route ID: 39108, Service ID: 5, Stop Sequence: 1
#
# Current Time: 10:00:30
# No new bus data available, retaining previous state.
#
# Current Time: 10:01:00
# Route: 2, Trip ID: 39101-0-5-67674, Stop: 39004, Arrival Time: 10:01:00, Departure Time: 10:01:00, Stop Name: DERMAN HASTANESI YANI, Direction ID: 0, Stop Lat: 41.4038497, Stop Lon: 27.355189, Route ID: 39101, Service ID: 5, Stop Sequence: 4
# Route: 2, Trip ID: 39101-1-5-73648, Stop: 39022, Arrival Time: 10:01:00, Departure Time: 10:01:00, Stop Name: TOTAL BENZINLIK, Direction ID: 1, Stop Lat: 41.401431, Stop Lon: 27.370574, Route ID: 39101, Service ID: 5, Stop Sequence: 3
# Route: 3, Trip ID: 39102-0-5-72592, Stop: 39254, Arrival Time: 10:01:00, Departure Time: 10:01:00, Stop Name: PAZAR YERİ, Direction ID: 0, Stop Lat: 41.4004665, Stop Lon: 27.3454649, Route ID: 39102, Service ID: 5, Stop Sequence: 1
# Route: 3, Trip ID: 39102-1-5-72418, Stop: 39257, Arrival Time: 10:01:00, Departure Time: 10:01:00, Stop Name: ALYA KONUTLARI-1, Direction ID: 1, Stop Lat: 41.3887007, Stop Lon: 27.3615173, Route ID: 39102, Service ID: 5, Stop Sequence: 2
# Route: 4, Trip ID: 39103-1-5-74768, Stop: 39406, Arrival Time: 10:01:00, Departure Time: 10:01:00, Stop Name: FİDANLIK, Direction ID: 1, Stop Lat: 41.3560923, Stop Lon: 27.3257803, Route ID: 39103, Service ID: 5, Stop Sequence: 1
# Route: 5, Trip ID: 39104-1-5-36111, Stop: 39259, Arrival Time: 10:01:00, Departure Time: 10:01:00, Stop Name: PAZARYERİ SON, Direction ID: 1, Stop Lat: 41.4011989, Stop Lon: 27.345925, Route ID: 39104, Service ID: 5, Stop Sequence: 5
# Route: 6, Trip ID: 39105-1-5-42354, Stop: 39209, Arrival Time: 10:01:00, Departure Time: 10:01:00, Stop Name: TOSUN KIRAATHANESİ 2, Direction ID: 1, Stop Lat: 41.402379, Stop Lon: 27.372098, Route ID: 39105, Service ID: 5, Stop Sequence: 2
# Route: 8, Trip ID: 39107-0-5-58004, Stop: 39002, Arrival Time: 10:01:00, Departure Time: 10:01:00, Stop Name: ONUR MARKET, Direction ID: 0, Stop Lat: 41.4057141, Stop Lon: 27.35077, Route ID: 39107, Service ID: 5, Stop Sequence: 4
# Route: 9, Trip ID: 39108-0-5-59270, Stop: 39227, Arrival Time: 10:01:00, Departure Time: 10:01:00, Stop Name: YILDIZ PARK, Direction ID: 0, Stop Lat: 41.3991341, Stop Lon: 27.3701119, Route ID: 39108, Service ID: 5, Stop Sequence: 6
# Route: 9, Trip ID: 39108-1-5-58804, Stop: 39256, Arrival Time: 10:01:00, Departure Time: 10:01:00, Stop Name: HÜKÜMET KONAĞI, Direction ID: 1, Stop Lat: 41.3897138, Stop Lon: 27.37091, Route ID: 39108, Service ID: 5, Stop Sequence: 2
# Trip ID 39103-0-5-73067 has completed its trip and has been removed.
# Trip ID 39105-0-5-42656 has completed its trip and has been removed.
#
# Current Time: 10:01:30
# No new bus data available, retaining previous state.
#
# Current Time: 10:02:00
# Route: 2, Trip ID: 39101-0-5-67674, Stop: 39039, Arrival Time: 10:02:00, Departure Time: 10:02:00, Stop Name: NOKTA, Direction ID: 0, Stop Lat: 41.4036222, Stop Lon: 27.3640173, Route ID: 39101, Service ID: 5, Stop Sequence: 5
# Route: 2, Trip ID: 39101-1-5-73648, Stop: 39051, Arrival Time: 10:02:00, Departure Time: 10:02:00, Stop Name: NOKTA DONUS, Direction ID: 1, Stop Lat: 41.403752, Stop Lon: 27.364022, Route ID: 39101, Service ID: 5, Stop Sequence: 4
# Route: 3, Trip ID: 39102-0-5-72592, Stop: 39001, Arrival Time: 10:02:00, Departure Time: 10:02:00, Stop Name: TERMINAL, Direction ID: 0, Stop Lat: 41.4045373, Stop Lon: 27.347064, Route ID: 39102, Service ID: 5, Stop Sequence: 2
# Route: 3, Trip ID: 39102-1-5-72418, Stop: 39083, Arrival Time: 10:02:00, Departure Time: 10:02:00, Stop Name: CARIKCI PARKI, Direction ID: 1, Stop Lat: 41.3937538, Stop Lon: 27.3628368, Route ID: 39102, Service ID: 5, Stop Sequence: 3
# Route: 4, Trip ID: 39103-1-5-74768, Stop: 39402, Arrival Time: 10:02:00, Departure Time: 10:02:00, Stop Name: DURAK MAHALLESİ CAMİSİ, Direction ID: 1, Stop Lat: 41.3568291, Stop Lon: 27.3353357, Route ID: 39103, Service ID: 5, Stop Sequence: 2
# Route: 6, Trip ID: 39105-1-5-42354, Stop: 39042, Arrival Time: 10:02:00, Departure Time: 10:02:00, Stop Name: PINAR MARKET, Direction ID: 1, Stop Lat: 41.405613, Stop Lon: 27.36857, Route ID: 39105, Service ID: 5, Stop Sequence: 3
# Route: 7, Trip ID: 39106-0-5-60047, Stop: 39254, Arrival Time: 10:02:00, Departure Time: 10:02:00, Stop Name: PAZAR YERİ, Direction ID: 0, Stop Lat: 41.4004665, Stop Lon: 27.3454649, Route ID: 39106, Service ID: 5, Stop Sequence: 1
# Route: 8, Trip ID: 39107-0-5-58004, Stop: 39004, Arrival Time: 10:02:00, Departure Time: 10:02:00, Stop Name: DERMAN HASTANESI YANI, Direction ID: 0, Stop Lat: 41.4038497, Stop Lon: 27.355189, Route ID: 39107, Service ID: 5, Stop Sequence: 5
# Route: 9, Trip ID: 39108-0-5-59270, Stop: 39256, Arrival Time: 10:02:00, Departure Time: 10:02:00, Stop Name: HÜKÜMET KONAĞI, Direction ID: 0, Stop Lat: 41.3897138, Stop Lon: 27.37091, Route ID: 39108, Service ID: 5, Stop Sequence: 7
# Route: 9, Trip ID: 39108-1-5-58804, Stop: 39224, Arrival Time: 10:02:00, Departure Time: 10:02:00, Stop Name: ŞOK MARKET 2, Direction ID: 1, Stop Lat: 41.3942741, Stop Lon: 27.367255, Route ID: 39108, Service ID: 5, Stop Sequence: 3
# Trip ID 39104-1-5-36111 has completed its trip and has been removed.
#
# Current Time: 10:02:30
# No new bus data available, retaining previous state.
#
# Current Time: 10:03:00
# Route: 2, Trip ID: 39101-0-5-67674, Stop: 39302, Arrival Time: 10:03:00, Departure Time: 10:03:00, Stop Name: YENİ HASTANE, Direction ID: 0, Stop Lat: 41.3984104, Stop Lon: 27.3736511, Route ID: 39101, Service ID: 5, Stop Sequence: 6
# Route: 2, Trip ID: 39101-1-5-73648, Stop: 39029, Arrival Time: 10:03:00, Departure Time: 10:03:00, Stop Name: KONGRE MEYDANI, Direction ID: 1, Stop Lat: 41.4067234, Stop Lon: 27.3550605, Route ID: 39101, Service ID: 5, Stop Sequence: 5
# Route: 3, Trip ID: 39102-0-5-72592, Stop: 39002, Arrival Time: 10:03:00, Departure Time: 10:03:00, Stop Name: ONUR MARKET, Direction ID: 0, Stop Lat: 41.4057141, Stop Lon: 27.35077, Route ID: 39102, Service ID: 5, Stop Sequence: 3
# Route: 3, Trip ID: 39102-1-5-72418, Stop: 39085, Arrival Time: 10:03:00, Departure Time: 10:03:00, Stop Name: LEVENT TAKSI, Direction ID: 1, Stop Lat: 41.395453, Stop Lon: 27.3573157, Route ID: 39102, Service ID: 5, Stop Sequence: 4
# Route: 4, Trip ID: 39103-0-5-73068, Stop: 39254, Arrival Time: 10:03:00, Departure Time: 10:03:00, Stop Name: PAZAR YERİ, Direction ID: 0, Stop Lat: 41.4004665, Stop Lon: 27.3454649, Route ID: 39103, Service ID: 5, Stop Sequence: 1
# Route: 4, Trip ID: 39103-1-5-74768, Stop: 39195, Arrival Time: 10:03:00, Departure Time: 10:03:00, Stop Name: İSTASYON ÇIKIŞ, Direction ID: 1, Stop Lat: 41.361849, Stop Lon: 27.3368955, Route ID: 39103, Service ID: 5, Stop Sequence: 3
# Route: 6, Trip ID: 39105-1-5-42354, Stop: 39051, Arrival Time: 10:03:00, Departure Time: 10:03:00, Stop Name: NOKTA DONUS, Direction ID: 1, Stop Lat: 41.403752, Stop Lon: 27.364022, Route ID: 39105, Service ID: 5, Stop Sequence: 4
# Route: 7, Trip ID: 39106-0-5-60047, Stop: 39001, Arrival Time: 10:03:00, Departure Time: 10:03:00, Stop Name: TERMINAL, Direction ID: 0, Stop Lat: 41.4045373, Stop Lon: 27.347064, Route ID: 39106, Service ID: 5, Stop Sequence: 2
# Route: 8, Trip ID: 39107-0-5-58004, Stop: 39098, Arrival Time: 10:03:00, Departure Time: 10:03:00, Stop Name: SEYTAN DURAGI, Direction ID: 0, Stop Lat: 41.396245, Stop Lon: 27.352848, Route ID: 39107, Service ID: 5, Stop Sequence: 6
# Route: 9, Trip ID: 39108-1-5-58804, Stop: 39227, Arrival Time: 10:03:00, Departure Time: 10:03:00, Stop Name: YILDIZ PARK, Direction ID: 1, Stop Lat: 41.3991341, Stop Lon: 27.3701119, Route ID: 39108, Service ID: 5, Stop Sequence: 4
# Trip ID 39108-0-5-59270 has completed its trip and has been removed.
#
# Current Time: 10:03:30
# No new bus data available, retaining previous state.
#
# Current Time: 10:04:00
# Route: 2, Trip ID: 39101-1-5-73648, Stop: 39259, Arrival Time: 10:04:00, Departure Time: 10:04:00, Stop Name: PAZARYERİ SON, Direction ID: 1, Stop Lat: 41.4011989, Stop Lon: 27.345925, Route ID: 39101, Service ID: 5, Stop Sequence: 6
# Route: 3, Trip ID: 39102-0-5-72592, Stop: 39004, Arrival Time: 10:04:00, Departure Time: 10:04:00, Stop Name: DERMAN HASTANESI YANI, Direction ID: 0, Stop Lat: 41.4038497, Stop Lon: 27.355189, Route ID: 39102, Service ID: 5, Stop Sequence: 4
# Route: 3, Trip ID: 39102-1-5-72418, Stop: 39088, Arrival Time: 10:04:00, Departure Time: 10:04:00, Stop Name: DAMAK, Direction ID: 1, Stop Lat: 41.3984353, Stop Lon: 27.3616865, Route ID: 39102, Service ID: 5, Stop Sequence: 5
# Route: 4, Trip ID: 39103-0-5-73068, Stop: 39001, Arrival Time: 10:04:00, Departure Time: 10:04:00, Stop Name: TERMINAL, Direction ID: 0, Stop Lat: 41.4045373, Stop Lon: 27.347064, Route ID: 39103, Service ID: 5, Stop Sequence: 2
# Route: 4, Trip ID: 39103-1-5-74768, Stop: 39292, Arrival Time: 10:04:00, Departure Time: 10:04:00, Stop Name: 39 Burda, Direction ID: 1, Stop Lat: 41.38645, Stop Lon: 27.3477409, Route ID: 39103, Service ID: 5, Stop Sequence: 4
# Route: 6, Trip ID: 39105-1-5-42354, Stop: 39259, Arrival Time: 10:04:00, Departure Time: 10:04:00, Stop Name: PAZARYERİ SON, Direction ID: 1, Stop Lat: 41.4011989, Stop Lon: 27.345925, Route ID: 39105, Service ID: 5, Stop Sequence: 5
# Route: 7, Trip ID: 39106-0-5-60047, Stop: 39002, Arrival Time: 10:04:00, Departure Time: 10:04:00, Stop Name: ONUR MARKET, Direction ID: 0, Stop Lat: 41.4057141, Stop Lon: 27.35077, Route ID: 39106, Service ID: 5, Stop Sequence: 3
# Route: 7, Trip ID: 39106-1-5-34482, Stop: 39292, Arrival Time: 10:04:00, Departure Time: 10:04:00, Stop Name: 39 Burda, Direction ID: 1, Stop Lat: 41.38645, Stop Lon: 27.3477409, Route ID: 39106, Service ID: 5, Stop Sequence: 1
# Route: 8, Trip ID: 39107-0-5-58004, Stop: 39140, Arrival Time: 10:04:00, Departure Time: 10:04:00, Stop Name: NEFES HASTANESİ, Direction ID: 0, Stop Lat: 41.39296, Stop Lon: 27.358394, Route ID: 39107, Service ID: 5, Stop Sequence: 7
# Route: 9, Trip ID: 39108-1-5-58804, Stop: 39051, Arrival Time: 10:04:00, Departure Time: 10:04:00, Stop Name: NOKTA DONUS, Direction ID: 1, Stop Lat: 41.403752, Stop Lon: 27.364022, Route ID: 39108, Service ID: 5, Stop Sequence: 5
# Trip ID 39101-0-5-67674 has completed its trip and has been removed.
#
# Current Time: 10:04:30
# No new bus data available, retaining previous state.
#
# Current Time: 10:05:00
# Route: 2, Trip ID: 39101-1-5-73649, Stop: 39302, Arrival Time: 10:05:00, Departure Time: 10:05:00, Stop Name: YENİ HASTANE, Direction ID: 1, Stop Lat: 41.3984104, Stop Lon: 27.3736511, Route ID: 39101, Service ID: 5, Stop Sequence: 1
# Route: 3, Trip ID: 39102-0-5-72592, Stop: 39180, Arrival Time: 10:05:00, Departure Time: 10:05:00, Stop Name: SİGORTA, Direction ID: 0, Stop Lat: 41.401702, Stop Lon: 27.3637845, Route ID: 39102, Service ID: 5, Stop Sequence: 5
# Route: 3, Trip ID: 39102-1-5-72418, Stop: 39189, Arrival Time: 10:05:00, Departure Time: 10:05:00, Stop Name: SİGORTA 2, Direction ID: 1, Stop Lat: 41.4017148, Stop Lon: 27.3638746, Route ID: 39102, Service ID: 5, Stop Sequence: 6
# Route: 4, Trip ID: 39103-0-5-73068, Stop: 39002, Arrival Time: 10:05:00, Departure Time: 10:05:00, Stop Name: ONUR MARKET, Direction ID: 0, Stop Lat: 41.4057141, Stop Lon: 27.35077, Route ID: 39103, Service ID: 5, Stop Sequence: 3
# Route: 4, Trip ID: 39103-1-5-74768, Stop: 39109, Arrival Time: 10:05:00, Departure Time: 10:05:00, Stop Name: AYDINKENT, Direction ID: 1, Stop Lat: 41.3895136, Stop Lon: 27.349547, Route ID: 39103, Service ID: 5, Stop Sequence: 5
# Route: 5, Trip ID: 39104-0-5-46998, Stop: 39254, Arrival Time: 10:05:00, Departure Time: 10:05:00, Stop Name: PAZAR YERİ, Direction ID: 0, Stop Lat: 41.4004665, Stop Lon: 27.3454649, Route ID: 39104, Service ID: 5, Stop Sequence: 1
# Route: 6, Trip ID: 39105-0-5-42657, Stop: 39254, Arrival Time: 10:05:00, Departure Time: 10:05:00, Stop Name: PAZAR YERİ, Direction ID: 0, Stop Lat: 41.4004665, Stop Lon: 27.3454649, Route ID: 39105, Service ID: 5, Stop Sequence: 1
# Route: 7, Trip ID: 39106-0-5-60047, Stop: 39004, Arrival Time: 10:05:00, Departure Time: 10:05:00, Stop Name: DERMAN HASTANESI YANI, Direction ID: 0, Stop Lat: 41.4038497, Stop Lon: 27.355189, Route ID: 39106, Service ID: 5, Stop Sequence: 4
# Route: 7, Trip ID: 39106-1-5-34482, Stop: 39293, Arrival Time: 10:05:00, Departure Time: 10:05:00, Stop Name: AKIM KOLEJI, Direction ID: 1, Stop Lat: 41.3914787, Stop Lon: 27.3497499, Route ID: 39106, Service ID: 5, Stop Sequence: 2
# Route: 8, Trip ID: 39107-0-5-58004, Stop: 39148, Arrival Time: 10:05:00, Departure Time: 10:05:00, Stop Name: TOKİ KIZ YURDU, Direction ID: 0, Stop Lat: 41.382753, Stop Lon: 27.3604126, Route ID: 39107, Service ID: 5, Stop Sequence: 8
# Route: 9, Trip ID: 39108-1-5-58804, Stop: 39259, Arrival Time: 10:05:00, Departure Time: 10:05:00, Stop Name: PAZARYERİ SON, Direction ID: 1, Stop Lat: 41.4011989, Stop Lon: 27.345925, Route ID: 39108, Service ID: 5, Stop Sequence: 6
# Trip ID 39101-1-5-73648 has completed its trip and has been removed.
# Trip ID 39105-1-5-42354 has completed its trip and has been removed.
#
# Current Time: 10:05:30
# No new bus data available, retaining previous state.
#
# Current Time: 10:06:00
# Route: 2, Trip ID: 39101-0-5-67675, Stop: 39254, Arrival Time: 10:06:00, Departure Time: 10:06:00, Stop Name: PAZAR YERİ, Direction ID: 0, Stop Lat: 41.4004665, Stop Lon: 27.3454649, Route ID: 39101, Service ID: 5, Stop Sequence: 1
# Route: 2, Trip ID: 39101-1-5-73649, Stop: 39020, Arrival Time: 10:06:00, Departure Time: 10:06:00, Stop Name: HEAS LOJMANLARI, Direction ID: 1, Stop Lat: 41.3997627, Stop Lon: 27.3763757, Route ID: 39101, Service ID: 5, Stop Sequence: 2
# Route: 3, Trip ID: 39102-0-5-72592, Stop: 39185, Arrival Time: 10:06:00, Departure Time: 10:06:00, Stop Name: LEVENT TAKSI 2, Direction ID: 0, Stop Lat: 41.3953985, Stop Lon: 27.3572753, Route ID: 39102, Service ID: 5, Stop Sequence: 6
# Route: 3, Trip ID: 39102-1-5-72418, Stop: 39264, Arrival Time: 10:06:00, Departure Time: 10:06:00, Stop Name: ORDUEVİ, Direction ID: 1, Stop Lat: 41.4041967, Stop Lon: 27.3558385, Route ID: 39102, Service ID: 5, Stop Sequence: 7
# Route: 4, Trip ID: 39103-0-5-73068, Stop: 39004, Arrival Time: 10:06:00, Departure Time: 10:06:00, Stop Name: DERMAN HASTANESI YANI, Direction ID: 0, Stop Lat: 41.4038497, Stop Lon: 27.355189, Route ID: 39103, Service ID: 5, Stop Sequence: 4
# Route: 4, Trip ID: 39103-1-5-74768, Stop: 39199, Arrival Time: 10:06:00, Departure Time: 10:06:00, Stop Name: SEYTAN DURAGI 2, Direction ID: 1, Stop Lat: 41.3961442, Stop Lon: 27.3530195, Route ID: 39103, Service ID: 5, Stop Sequence: 6
# Route: 5, Trip ID: 39104-0-5-46998, Stop: 39001, Arrival Time: 10:06:00, Departure Time: 10:06:00, Stop Name: TERMINAL, Direction ID: 0, Stop Lat: 41.4045373, Stop Lon: 27.347064, Route ID: 39104, Service ID: 5, Stop Sequence: 2
# Route: 6, Trip ID: 39105-0-5-42657, Stop: 39001, Arrival Time: 10:06:00, Departure Time: 10:06:00, Stop Name: TERMINAL, Direction ID: 0, Stop Lat: 41.4045373, Stop Lon: 27.347064, Route ID: 39105, Service ID: 5, Stop Sequence: 2
# Route: 7, Trip ID: 39106-0-5-60047, Stop: 39131, Arrival Time: 10:06:00, Departure Time: 10:06:00, Stop Name: ADLİYE2, Direction ID: 0, Stop Lat: 41.397221, Stop Lon: 27.3486003, Route ID: 39106, Service ID: 5, Stop Sequence: 5
# Route: 7, Trip ID: 39106-1-5-34482, Stop: 39096, Arrival Time: 10:06:00, Departure Time: 10:06:00, Stop Name: ASKERI LOJMANLAR2, Direction ID: 1, Stop Lat: 41.399871, Stop Lon: 27.354358, Route ID: 39106, Service ID: 5, Stop Sequence: 3
# Route: 8, Trip ID: 39107-0-5-58004, Stop: 39295, Arrival Time: 10:06:00, Departure Time: 10:06:00, Stop Name: LYSA, Direction ID: 0, Stop Lat: 41.3967604, Stop Lon: 27.3725002, Route ID: 39107, Service ID: 5, Stop Sequence: 9
# Route: 9, Trip ID: 39108-0-5-59271, Stop: 39254, Arrival Time: 10:06:00, Departure Time: 10:06:00, Stop Name: PAZAR YERİ, Direction ID: 0, Stop Lat: 41.4004665, Stop Lon: 27.3454649, Route ID: 39108, Service ID: 5, Stop Sequence: 1
# Trip ID 39108-1-5-58804 has completed its trip and has been removed.
#
# Current Time: 10:06:30
# No new bus data available, retaining previous state.
#
# Current Time: 10:07:00
# Route: 2, Trip ID: 39101-0-5-67675, Stop: 39001, Arrival Time: 10:07:00, Departure Time: 10:07:00, Stop Name: TERMINAL, Direction ID: 0, Stop Lat: 41.4045373, Stop Lon: 27.347064, Route ID: 39101, Service ID: 5, Stop Sequence: 2
# Route: 2, Trip ID: 39101-1-5-73649, Stop: 39022, Arrival Time: 10:07:00, Departure Time: 10:07:00, Stop Name: TOTAL BENZINLIK, Direction ID: 1, Stop Lat: 41.401431, Stop Lon: 27.370574, Route ID: 39101, Service ID: 5, Stop Sequence: 3
# Route: 3, Trip ID: 39102-0-5-72592, Stop: 39187, Arrival Time: 10:07:00, Departure Time: 10:07:00, Stop Name: CARIKCI PARKI 2, Direction ID: 0, Stop Lat: 41.3938141, Stop Lon: 27.3627523, Route ID: 39102, Service ID: 5, Stop Sequence: 7
# Route: 3, Trip ID: 39102-1-5-72418, Stop: 39259, Arrival Time: 10:07:00, Departure Time: 10:07:00, Stop Name: PAZARYERİ SON, Direction ID: 1, Stop Lat: 41.4011989, Stop Lon: 27.345925, Route ID: 39102, Service ID: 5, Stop Sequence: 8
# Route: 4, Trip ID: 39103-0-5-73068, Stop: 39098, Arrival Time: 10:07:00, Departure Time: 10:07:00, Stop Name: SEYTAN DURAGI, Direction ID: 0, Stop Lat: 41.396245, Stop Lon: 27.352848, Route ID: 39103, Service ID: 5, Stop Sequence: 5
# Route: 4, Trip ID: 39103-1-5-74768, Stop: 39264, Arrival Time: 10:07:00, Departure Time: 10:07:00, Stop Name: ORDUEVİ, Direction ID: 1, Stop Lat: 41.4041967, Stop Lon: 27.3558385, Route ID: 39103, Service ID: 5, Stop Sequence: 7
# Route: 5, Trip ID: 39104-0-5-46998, Stop: 39002, Arrival Time: 10:07:00, Departure Time: 10:07:00, Stop Name: ONUR MARKET, Direction ID: 0, Stop Lat: 41.4057141, Stop Lon: 27.35077, Route ID: 39104, Service ID: 5, Stop Sequence: 3
# Route: 6, Trip ID: 39105-0-5-42657, Stop: 39002, Arrival Time: 10:07:00, Departure Time: 10:07:00, Stop Name: ONUR MARKET, Direction ID: 0, Stop Lat: 41.4057141, Stop Lon: 27.35077, Route ID: 39105, Service ID: 5, Stop Sequence: 3
# Route: 7, Trip ID: 39106-0-5-60047, Stop: 39292, Arrival Time: 10:07:00, Departure Time: 10:07:00, Stop Name: 39 Burda, Direction ID: 0, Stop Lat: 41.38645, Stop Lon: 27.3477409, Route ID: 39106, Service ID: 5, Stop Sequence: 6
# Route: 7, Trip ID: 39106-1-5-34482, Stop: 39259, Arrival Time: 10:07:00, Departure Time: 10:07:00, Stop Name: PAZARYERİ SON, Direction ID: 1, Stop Lat: 41.4011989, Stop Lon: 27.345925, Route ID: 39106, Service ID: 5, Stop Sequence: 4
# Route: 9, Trip ID: 39108-0-5-59271, Stop: 39001, Arrival Time: 10:07:00, Departure Time: 10:07:00, Stop Name: TERMINAL, Direction ID: 0, Stop Lat: 41.4045373, Stop Lon: 27.347064, Route ID: 39108, Service ID: 5, Stop Sequence: 2
# Trip ID 39107-0-5-58004 has completed its trip and has been removed.
#
# Current Time: 10:07:30
# No new bus data available, retaining previous state.
#
# Current Time: 10:08:00
# Route: 2, Trip ID: 39101-0-5-67675, Stop: 39002, Arrival Time: 10:08:00, Departure Time: 10:08:00, Stop Name: ONUR MARKET, Direction ID: 0, Stop Lat: 41.4057141, Stop Lon: 27.35077, Route ID: 39101, Service ID: 5, Stop Sequence: 3
# Route: 2, Trip ID: 39101-1-5-73649, Stop: 39051, Arrival Time: 10:08:00, Departure Time: 10:08:00, Stop Name: NOKTA DONUS, Direction ID: 1, Stop Lat: 41.403752, Stop Lon: 27.364022, Route ID: 39101, Service ID: 5, Stop Sequence: 4
# Route: 3, Trip ID: 39102-0-5-72592, Stop: 39257, Arrival Time: 10:08:00, Departure Time: 10:08:00, Stop Name: ALYA KONUTLARI-1, Direction ID: 0, Stop Lat: 41.3887007, Stop Lon: 27.3615173, Route ID: 39102, Service ID: 5, Stop Sequence: 8
# Route: 4, Trip ID: 39103-0-5-73068, Stop: 39292, Arrival Time: 10:08:00, Departure Time: 10:08:00, Stop Name: 39 Burda, Direction ID: 0, Stop Lat: 41.38645, Stop Lon: 27.3477409, Route ID: 39103, Service ID: 5, Stop Sequence: 6
# Route: 4, Trip ID: 39103-1-5-74768, Stop: 39259, Arrival Time: 10:08:00, Departure Time: 10:08:00, Stop Name: PAZARYERİ SON, Direction ID: 1, Stop Lat: 41.4011989, Stop Lon: 27.345925, Route ID: 39103, Service ID: 5, Stop Sequence: 8
# Route: 5, Trip ID: 39104-0-5-46998, Stop: 39004, Arrival Time: 10:08:00, Departure Time: 10:08:00, Stop Name: DERMAN HASTANESI YANI, Direction ID: 0, Stop Lat: 41.4038497, Stop Lon: 27.355189, Route ID: 39104, Service ID: 5, Stop Sequence: 4
# Route: 6, Trip ID: 39105-0-5-42657, Stop: 39004, Arrival Time: 10:08:00, Departure Time: 10:08:00, Stop Name: DERMAN HASTANESI YANI, Direction ID: 0, Stop Lat: 41.4038497, Stop Lon: 27.355189, Route ID: 39105, Service ID: 5, Stop Sequence: 4
# Route: 8, Trip ID: 39107-0-5-58005, Stop: 39291, Arrival Time: 10:08:00, Departure Time: 10:08:00, Stop Name: MINIBUS GARAJI, Direction ID: 0, Stop Lat: 41.3963037, Stop Lon: 27.3419168, Route ID: 39107, Service ID: 5, Stop Sequence: 1
# Route: 9, Trip ID: 39108-0-5-59271, Stop: 39002, Arrival Time: 10:08:00, Departure Time: 10:08:00, Stop Name: ONUR MARKET, Direction ID: 0, Stop Lat: 41.4057141, Stop Lon: 27.35077, Route ID: 39108, Service ID: 5, Stop Sequence: 3
# Trip ID 39102-1-5-72418 has completed its trip and has been removed.
# Trip ID 39106-0-5-60047 has completed its trip and has been removed.
# Trip ID 39106-1-5-34482 has completed its trip and has been removed.
#
# Current Time: 10:08:30
# No new bus data available, retaining previous state.
#
# Current Time: 10:09:00
# Route: 2, Trip ID: 39101-0-5-67675, Stop: 39004, Arrival Time: 10:09:00, Departure Time: 10:09:00, Stop Name: DERMAN HASTANESI YANI, Direction ID: 0, Stop Lat: 41.4038497, Stop Lon: 27.355189, Route ID: 39101, Service ID: 5, Stop Sequence: 4
# Route: 2, Trip ID: 39101-1-5-73649, Stop: 39029, Arrival Time: 10:09:00, Departure Time: 10:09:00, Stop Name: KONGRE MEYDANI, Direction ID: 1, Stop Lat: 41.4067234, Stop Lon: 27.3550605, Route ID: 39101, Service ID: 5, Stop Sequence: 5
# Route: 3, Trip ID: 39102-0-5-72592, Stop: 39290, Arrival Time: 10:09:00, Departure Time: 10:09:00, Stop Name: ALYA 3, Direction ID: 0, Stop Lat: 41.3874379, Stop Lon: 27.3672607, Route ID: 39102, Service ID: 5, Stop Sequence: 9
# Route: 4, Trip ID: 39103-0-5-73068, Stop: 39193, Arrival Time: 10:09:00, Departure Time: 10:09:00, Stop Name: MEYDAN, Direction ID: 0, Stop Lat: 41.3569063, Stop Lon: 27.3349273, Route ID: 39103, Service ID: 5, Stop Sequence: 7
# Route: 5, Trip ID: 39104-0-5-46998, Stop: 39039, Arrival Time: 10:09:00, Departure Time: 10:09:00, Stop Name: NOKTA, Direction ID: 0, Stop Lat: 41.4036222, Stop Lon: 27.3640173, Route ID: 39104, Service ID: 5, Stop Sequence: 5
# Route: 6, Trip ID: 39105-0-5-42657, Stop: 39039, Arrival Time: 10:09:00, Departure Time: 10:09:00, Stop Name: NOKTA, Direction ID: 0, Stop Lat: 41.4036222, Stop Lon: 27.3640173, Route ID: 39105, Service ID: 5, Stop Sequence: 5
# Route: 8, Trip ID: 39107-0-5-58005, Stop: 39254, Arrival Time: 10:09:00, Departure Time: 10:09:00, Stop Name: PAZAR YERİ, Direction ID: 0, Stop Lat: 41.4004665, Stop Lon: 27.3454649, Route ID: 39107, Service ID: 5, Stop Sequence: 2
# Route: 9, Trip ID: 39108-0-5-59271, Stop: 39004, Arrival Time: 10:09:00, Departure Time: 10:09:00, Stop Name: DERMAN HASTANESI YANI, Direction ID: 0, Stop Lat: 41.4038497, Stop Lon: 27.355189, Route ID: 39108, Service ID: 5, Stop Sequence: 4
# Trip ID 39103-1-5-74768 has completed its trip and has been removed.
#
# Current Time: 10:09:30
# No new bus data available, retaining previous state.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 258
#     256 start_time_str = get_time_input("Enter start time (HH:MM:SS): ")
#     257 end_time_str = get_time_input("Enter end time (HH:MM:SS): ")
# --> 258 dynamic_update_service(start_time_str, end_time_str)
#
# Cell In[17], line 254, in dynamic_update_service(start_time_str, end_time_str)
#     251                         db.rollback()  # Rollback the transaction on error
#     253 current_datetime += timedelta(seconds=update_interval)
# --> 254 time.sleep(3)
#
# KeyboardInterrupt:
