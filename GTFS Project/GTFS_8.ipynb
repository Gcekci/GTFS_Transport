# %%
import pandas as pd
from datetime import datetime, timedelta
import folium
import time
from IPython.display import display, clear_output

# Load GTFS data
data_path = r"C:\Users\TULPAR\JupyterLab Projects\GTFS Project\dataset"
"C:\Users\TULPAR\JupyterLab Projects\GTFS Project"
stops = pd.read_csv(f"{data_path}/stops.txt")
routes = pd.read_csv(f"{data_path}/routes.txt")
trips = pd.read_csv(f"{data_path}/trips.txt")
stop_times = pd.read_csv(f"{data_path}/stop_times.txt")
calendar = pd.read_csv(f"{data_path}/calendar.txt")
shapes = pd.read_csv(f"{data_path}/shapes.txt")

# Function to convert times
def convert_time(time_str):
    try:
        # Split the time string
        parts = time_str.split(':')
        hours, minutes, seconds = int(parts[0]), int(parts[1]), int(parts[2])
        
        # If the hour is 24 or more, adjust the time
        if hours >= 24:
            hours -= 24
        # Return the adjusted time in HH:MM:SS format
        return f"{hours:02}:{minutes:02}:{seconds:02}"
    except ValueError as e:
        print(f"Error converting time: {time_str} - {e}")
        return None

# Apply the conversion to arrival_time and departure_time

stop_times['arrival_time'] = stop_times['arrival_time'].apply(convert_time)
stop_times['departure_time'] = stop_times['departure_time'].apply(convert_time)

# Drop rows with None values after conversion
stop_times = stop_times.dropna(subset=['arrival_time', 'departure_time'])

# Save the modified stop_times to a new file
stop_times.to_csv('stop_times_modified.txt', index=False)

print("Stops data:")
display(stops.head())

print("\nRoutes data:")
display(routes.head())

print("\nTrips data:")
display(trips.head())

print("\nStop Times data:")
display(stop_times)

print("\nCalendar data:")
display(calendar.head())

print("\nShapes data:")
display(shapes.head())

# Simulation parameters
#start_time = datetime.strptime('06:00:00', '%H:%M:%S')  # Simulation start time
now_time=datetime.now()
current_time=datetime.strptime(now_time.strftime('%H:%M:%S'),'%H:%M:%S')
print(current_time)
start_time=current_time

end_time = datetime.strptime('23:00:00', '%H:%M:%S')    # Simulation end time

print("Current time is: ", current_time)
time_step = timedelta(seconds=30)  # Simulation time step

# Initialize the map centered on the city
city_latitude = stops['stop_lat'].mean()
city_longitude = stops['stop_lon'].mean()
map = folium.Map(location=[city_latitude, city_longitude], zoom_start=12)

# Initialize buses
buses = [{
    'trip_id': trip.trip_id,
    'route_id': trip.route_id,
    'current_stop_sequence': 0,
    'current_time': current_time
} for trip in trips.itertuples()]




# Add stop markers to the map initially
def add_stop_markers(stops, map):
    stopNumber = 0 
    for stop in stops.itertuples():
        folium.Marker(
            location=[stop.stop_lat, stop.stop_lon],
            popup=f"Stop: {stop.stop_name}, Stop Number: {stopNumber}"
        ).add_to(map)
        stopNumber += 1
    return map

map = add_stop_markers(stops, map)

def create_lines(shapes, map):
    shape_locations = []
    
    for shape in shapes.itertuples():
        shape_locations.append([shape.shape_pt_lat, shape.shape_pt_lon])
    
    if len(shape_locations) > 1:
        folium.PolyLine(locations=shape_locations, color="red", dash_array='5', weight=2.5, opacity=1).add_to(map)
    return map

map = create_lines(shapes, map)

# Dictionary to store bus markers
bus_markers = {}


def update_bus_positions(buses, stop_times, current_time):
    updated_buses = []
    for bus in buses:
        trip_id = bus['trip_id']
        stop_times_for_trip = stop_times[stop_times['trip_id'] == trip_id]
        
        if not stop_times_for_trip.empty:
            current_stop_sequence = bus['current_stop_sequence']
            
            if current_stop_sequence < len(stop_times_for_trip):
                current_stop = stop_times_for_trip.iloc[current_stop_sequence]
                arrival_time = datetime.strptime(current_stop['arrival_time'], '%H:%M:%S')
                
                if current_time >= arrival_time:
                    bus['current_stop_sequence'] += 1
            
            if bus['current_stop_sequence'] < len(stop_times_for_trip):
                updated_buses.append(bus)
    return updated_buses



def visualize_buses(buses, stops, stop_times, map):
    for bus in buses:
        trip_id = bus['trip_id']
        current_stop_sequence = bus['current_stop_sequence']
        
        if current_stop_sequence > 0:
            stop_times_for_trip = stop_times[stop_times['trip_id'] == trip_id]
            
            if current_stop_sequence < len(stop_times_for_trip):
                current_stop_id = stop_times_for_trip.iloc[current_stop_sequence]['stop_id']
                stop = stops[stops['stop_id'] == current_stop_id]
                
                if not stop.empty:
                    folium.Marker(
                        location=[stop['stop_lat'].values[0], stop['stop_lon'].values[0]],
                        popup=f"Bus on route {bus['route_id']} at stop {stop['stop_name'].values[0]}"
                    ,icon=folium.Icon(color="red",icon="bus-simple", prefix='fa')).add_to(map)
    return map

# Simulation loop
while current_time <= end_time:
    buses = update_bus_positions(buses, stop_times, current_time)
    map = visualize_buses(buses, stops, stop_times, map)
    clear_output(wait=True)
    current_time += time_step
    display(map)
    # Adjust the sleep duration as needed
    time.sleep(30)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 165
#     163 clear_output(wait=True)
#     164 current_time += time_step
# --> 165 display(map)
#     166 # Adjust the sleep duration as needed
#     167 time.sleep(30)
#
# File c:\Users\TULPAR\anaconda3\Lib\site-packages\IPython\core\display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File c:\Users\TULPAR\anaconda3\Lib\site-packages\IPython\core\formatters.py:179, in DisplayFormatter.format(self, obj, include, exclude)
#     177 md = None
#     178 try:
# --> 179     data = formatter(obj)
#     180 except:
#     181     # FIXME: log the exception
#     182     raise
#
# File c:\Users\TULPAR\anaconda3\Lib\site-packages\decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File c:\Users\TULPAR\anaconda3\Lib\site-packages\IPython\core\formatters.py:223, in catch_format_error(method, self, *args, **kwargs)
#     221 """show traceback on failed format call"""
#     222 try:
# --> 223     r = method(self, *args, **kwargs)
#     224 except NotImplementedError:
#     225     # don't warn on NotImplementedErrors
#     226     return self._check_return(None, args[0])
#
# File c:\Users\TULPAR\anaconda3\Lib\site-packages\IPython\core\formatters.py:344, in BaseFormatter.__call__(self, obj)
#     342     method = get_real_method(obj, self.print_method)
#     343     if method is not None:
# --> 344         return method()
#     345     return None
#     346 else:
#
# File c:\Users\TULPAR\anaconda3\Lib\site-packages\folium\folium.py:319, in Map._repr_html_(self, **kwargs)
#     317     self._parent = None
#     318 else:
# --> 319     out = self._parent._repr_html_(**kwargs)
#     320 return out
#
# File c:\Users\TULPAR\anaconda3\Lib\site-packages\branca\element.py:343, in Figure._repr_html_(self, **kwargs)
#     341 def _repr_html_(self, **kwargs):
#     342     """Displays the Figure in a Jupyter notebook."""
# --> 343     html = escape(self.render(**kwargs))
#     344     if self.height is None:
#     345         iframe = (
#     346             '<div style="width:{width};">'
#     347             '<div style="position:relative;width:100%;height:0;padding-bottom:{ratio};">'  # noqa
#    (...)
#     353             '</div></div>'
#     354         ).format(html=html, width=self.width, ratio=self.ratio)
#
# File c:\Users\TULPAR\anaconda3\Lib\site-packages\branca\element.py:338, in Figure.render(self, **kwargs)
#     336 """Renders the HTML representation of the element."""
#     337 for name, child in self._children.items():
# --> 338     child.render(**kwargs)
#     339 return self._template.render(this=self, kwargs=kwargs)
#
# File c:\Users\TULPAR\anaconda3\Lib\site-packages\folium\folium.py:401, in Map.render(self, **kwargs)
#     374 figure.header.add_child(
#     375     Element(
#     376         "<style>html, body {"
#    (...)
#     384     name="css_style",
#     385 )
#     387 figure.header.add_child(
#     388     Element(
#     389         "<style>#map {"
#    (...)
#     398     name="map_style",
#     399 )
# --> 401 super().render(**kwargs)
#
# File c:\Users\TULPAR\anaconda3\Lib\site-packages\folium\elements.py:22, in JSCSSMixin.render(self, **kwargs)
#      19 for name, url in self.default_css:
#      20     figure.header.add_child(CssLink(url), name=name)
# ---> 22 super().render(**kwargs)
#
# File c:\Users\TULPAR\anaconda3\Lib\site-packages\branca\element.py:645, in MacroElement.render(self, **kwargs)
#     641     figure.script.add_child(Element(script(self, kwargs)),
#     642                             name=self.get_name())
#     644 for name, element in self._children.items():
# --> 645     element.render(**kwargs)
#
# File c:\Users\TULPAR\anaconda3\Lib\site-packages\folium\map.py:354, in Marker.render(self)
#     348 if self.location is None:
#     349     raise ValueError(
#     350         "{} location must be assigned when added directly to map.".format(
#     351             self._name
#     352         )
#     353     )
# --> 354 super().render()
#
# File c:\Users\TULPAR\anaconda3\Lib\site-packages\branca\element.py:645, in MacroElement.render(self, **kwargs)
#     641     figure.script.add_child(Element(script(self, kwargs)),
#     642                             name=self.get_name())
#     644 for name, element in self._children.items():
# --> 645     element.render(**kwargs)
#
# File c:\Users\TULPAR\anaconda3\Lib\site-packages\folium\map.py:448, in Popup.render(self, **kwargs)
#     442 figure = self.get_root()
#     443 assert isinstance(
#     444     figure, Figure
#     445 ), "You cannot render this Element if it is not in a Figure."
#     447 figure.script.add_child(
# --> 448     Element(self._template.render(this=self, kwargs=kwargs)),
#     449     name=self.get_name(),
#     450 )
#
# KeyboardInterrupt:
